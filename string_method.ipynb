# %%
string = "this is python class"

# %% [markdown]
# # string.capitalise()

# %%
string = "this is python class"
string.capitalize()  # convert the first character to upper case
# Out:
# 'This is python class'

# %% [markdown]
# # string.casefold()

# %%
string = "this is python class"
string.casefold()  # conert string into lower case
# Out:
# 'this is python class'

# %% [markdown]
# # string.center()

# %%
string = "this is python class"
# string.center(length,character) character is optional
string.center(30,' ')  # align the string in center
# Out:
# '     this is python class     '

# %% [markdown]
# # string.count()

# %%
string = "this is python class"
string.count("s") # returns no of time a value occur in string
# Out:
# 4

# %% [markdown]
# # string.encode()

# %%
string = "this is python class"
string.encode()
# Out:
# b'this is python class'

# %% [markdown]
# # txt.endswith()

# %%
txt = "this is my python class" 
# returns True if the string ends with the specified value, otherwise False
# we can use start and end in this but these are optinal (sting.endswith(value,start,end))
txt.endswith("class",0,10)
# Out:
# False

# %% [markdown]
# # string.expandtabs()

# %%
string = "this\tis\tpython\tclass"
string.expandtabs(10) # sets the tab size to specified number of whitespaces
# Out:
# 'this      is        python    class'

# %% [markdown]
# # txt.find()

# %%
txt = "this is my python class"
txt.find("t",4,) # search the given value and give their position ,gives -1 if not found
# Out:
# 13

# %% [markdown]
# # string.format()

# %%
string = "my name is {name}"
string.format(name = "kritika") # formats the value and insert them into string
# Out:
# 'my name is kritika'

# %% [markdown]
# # string.index()

# %%
string = "this is python class"
string.index("t",2,13) # finds the first occurance of value ,same as find but it doesn't give -1 if not found
# Out:
# 10

# %% [markdown]
# # statement.isalnum()

# %%
statement = "this is python class@"
statement.isalnum() # returns true if all the character are alphanumeric
# Out:
# False

# %% [markdown]
# # string.isalpha()

# %%
name = "kritika"
name.isalpha() # returns True if all characters in the string are in the alphabet
# Out:
# True

# %% [markdown]
# # name.isascii()

# %%
name = "kritika"
name.isascii() # returns True if all characters in the string are ascii characters
# Out:
# True

# %% [markdown]
# # num.isdecimal()

# %%
num = "123"
num.isdecimal() # returns True if all the characters are decimals (0-9)
# Out:
# True

# %% [markdown]
# # numder.isdigit()

# %%
numder = "123"
numder.isdigit() # returns True if all the characters are digits, otherwise False
# Out:
# True

# %% [markdown]
# # name.isidentifier()

# %%
name = "2kritika"
name.isidentifier() # returns True if the string is a valid identifier, otherwise False
# Out:
# False

# %% [markdown]
# # string.islower()

# %%
string = "this is python class"
string.islower() # returns True if all the characters are in lower case
# Out:
# True

# %% [markdown]
# # numder.isnumeric()

# %%
numder = "123"
numder.isnumeric() # returns True if all characters in the string are numeric
# Out:
# True

# %% [markdown]
# # statement.isprintable()

# %%
statement = "this is python class@\n"
statement.isprintable() 
# returns True if all the characters are printable, otherwise False
# Example of none printable character can be carriage return(\r)(moves to beginning of current line) and line feed(\n)(next line)
# Out:
# False

# %% [markdown]
# # name1.isspace()

# %%
name1 = "   "
name1.isspace() # returns True if all the characters in a string are whitespaces
# Out:
# True

# %% [markdown]
# # txt1.istitle()

# %%
txt1 = "This Is My First Class"
txt1.istitle() # True if all words in a text start with a upper case letter, AND the rest of the word are lower case letters
# Out:
# True

# %% [markdown]
# # txt2.isupper()

# %%
txt2 = "KRITIKA"
txt2.isupper() # Returns True if all characters in the string are upper case
# Out:
# True

# %% [markdown]
# # string1.join()

# %%
string1 = ("kriti","khushi","bhumi")
"#".join(string1) #takes all items in an iterable and joins them into one string.
# Out:
# 'kriti#khushi#bhumi'

# %% [markdown]
# # txt2.ljust()

# %%
txt2 = "KRITIKA"
txt2.ljust(20,"o") # left align the string, using a specified character (space is default) as the fill character
# Out:
# 'KRITIKAooooooooooooo'

# %% [markdown]
# # txt2.lower()

# %%
txt2 = "KRITIKA"
txt2.lower() # Converts a string into lower case
# Out:
# 'kritika'

# %% [markdown]
# # txt3.lstrip()

# %%
txt3 = "           people             "
txt3.lstrip() # removes any leading characters (space is the default leading character to remove)
# Out:
# 'people             '

# %% [markdown]
# # txt1.partition()

# %%
txt1 = "This Is My First Class"
txt1.partition("My") # searches for a specified string, and splits the string into a tuple containing three elements
# Out:
# ('This Is ', 'My', ' First Class')

# %% [markdown]
# # txt4.replace()

# %%
txt4 = "one one was a race horse, two two was one too."
txt4.replace("one", "three", 2) # replaces a specified phrase with another specified phrase
# cout is optional ,by default it replaces all are replaced
# Out:
# 'three three was a race horse, two two was one too.'

# %% [markdown]
# # txt1.rfind()

# %%
txt1 = "This Is My First Class"
# string.rfind(value, start, end) start and end are optional
txt1.rfind("s",4,19) #  finds the last occurrence of the specified value
# returns -1 if the value is not found
# Out:
# 14

# %% [markdown]
# # txt1.rindex()

# %%
txt1 = "This Is My First Class"
txt1.rindex("I") # same as r find but raises an exception if value not found
# Out:
# 5

# %% [markdown]
# # txt1.removeprefix()

# %%
txt1 = "This Is My First Class"
txt1.removeprefix("This ") # remove from the start of the string
# Out:
# 'Is My First Class'

# %% [markdown]
# # txt1.removesuffix()

# %%
txt1 = "This Is My First Class"
txt1.removesuffix("s") # remove from the end of the string
# Out:
# 'This Is My First Clas'

# %% [markdown]
# # txt2.rjust()

# %%
txt2 = "KRITIKA"
txt2.rjust(20,"o") # right align the string, using a specified character (space is default) as the fill character
# Out:
# 'oooooooooooooKRITIKA'

# %% [markdown]
# # txt5.rpartition()

# %%
txt5 = "I could eat bananas all day, bananas are my favorite fruit"
txt5.rpartition("bananas") # searches for the last occurrence of a specified string, and splits the string into a tuple containing three elements
# Out:
# ('I could eat bananas all day, ', 'bananas', ' are my favorite fruit')

# %% [markdown]
# # txt6.rsplit()

# %%
txt6 = "apple, banana, cherry"
txt6.rsplit(", ", 1) #  splits a string into a list, starting from the right
# If no "max" is specified, this method will return the same as the split() method
# setting the maxsplit parameter to 1, will return a list with 2 elements
# Out:
# ['apple, banana', 'cherry']

# %% [markdown]
# # txt3.rstrip()

# %%
txt3 = "           people             "
txt3.rstrip() #  removes any trailing characters (characters at the end a string), space is the default trailing character to remove
# Out:
# '           people'

# %% [markdown]
# # txt6.split()

# %%
txt6 = "apple, banana, cherry"
txt6.rsplit(", ") #  splits a string into a list
# Out:
# ['apple', 'banana', 'cherry']

# %% [markdown]
# # txt5.splitlines()

# %%
txt5 = "I could eat bananas all day\nbananas are my favorite fruit"
txt5.splitlines() # splits a string into a list. The splitting is done at line breaks
# Out:
# ['I could eat bananas all day', 'bananas are my favorite fruit']

# %% [markdown]
# # txt1.startswith()

# %%
txt1 = "This Is My First Class"
txt1.startswith("This") # returns True if the string starts with the specified value, otherwise False
# Out:
# True

# %% [markdown]
# # txt3.strip()

# %%
txt3 = "           people             "
txt3.strip() #  removes any leading, and trailing whitespaces
# Out:
# 'people'

# %% [markdown]
# # txt1.swapcase()

# %%
txt1 = "This Is My First Class"
txt1.swapcase() # returns a string where all the upper case letters are lower case and vice versa
# Out:
# 'tHIS iS mY fIRST cLASS'

# %% [markdown]
# # string1.title()

# %%
string1 = "welcome to my world"
string1.title() #  returns a string where the first character in every word is upper case
# If the word contains a number or a symbol, the first letter after that will be converted to upper case
# Out:
# 'Welcome To My World'

# %% [markdown]
# # string1.upper()

# %%
string1 = "welcome to my world"
string1.upper() #  returns a string where all characters are in upper case
# Out:
# 'WELCOME TO MY WORLD'

# %% [markdown]
# # string1.zfill()

# %%
string1 = "welcome to my world"
string1.zfill(30) # adds zeros (0) at the beginning of the string, until it reaches the specified length
# Out:
# '00000000000welcome to my world'
